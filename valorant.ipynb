# %%
import pandas as pd

# %%
score = pd.read_csv('dataset/vct_2021/matches/scores.csv')
score
# Out:
#                                        Tournament            Stage  \
# 0                         Valorant Champions 2021      Group Stage
# 1                         Valorant Champions 2021      Group Stage
# 2                         Valorant Champions 2021      Group Stage
# 3                         Valorant Champions 2021      Group Stage
# 4                         Valorant Champions 2021      Group Stage
# ...                                           ...              ...
# 7064  Champions Tour LATAM Stage 1: Challengers 1  Main Event: LAN
# 7065  Champions Tour LATAM Stage 1: Challengers 1  Main Event: LAS
# 7066  Champions Tour LATAM Stage 1: Challengers 1  Main Event: LAN
# 7067  Champions Tour LATAM Stage 1: Challengers 1  Main Event: LAS
# 7068  Champions Tour LATAM Stage 1: Challengers 1  Main Event: LAN
#
#              Match Type                       Match Name            Team A  \
# 0           Opening (D)    Vision Strikers vs FULL SENSE   Vision Strikers
# ...
