# %% [markdown]
# Fase 2 - Projeto Final ICD

# %% [markdown]
# Importando de bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importando o dataset de agents pick do vct 2022

# %%
agents_vct2022= pd.read_csv('dataset/vct_2022/agents/agents_pick_rates.csv')
agents_vct2022
#A ideia é pegar apenas o "All Maps" e o "All Match types" de cada região
# Out:
#                                                Tournament       Stage  \
# 0       Champions Tour South America: Last Chance Qual...  Main Event
# 1       Champions Tour South America: Last Chance Qual...  Main Event
# 2       Champions Tour South America: Last Chance Qual...  Main Event
# 3       Champions Tour South America: Last Chance Qual...  Main Event
# 4       Champions Tour South America: Last Chance Qual...  Main Event
# ...                                                   ...         ...
# 126817  Champions Tour North America Stage 1: Challengers  All Stages
# 126818  Champions Tour North America Stage 1: Challengers  All Stages
# 126819  Champions Tour North America Stage 1: Challengers  All Stages
# 126820  Champions Tour North America Stage 1: Challengers  All Stages
# 126821  Champions Tour North America Stage 1: Challengers  All Stages
#
#                  Match Type       Map     Agent Pick Rate
# 0       Upper Quarterfinals  All Maps   chamber       80%
# ...

# %%
math_type = "All Match Types"
map = "All Maps"
stage = "All Stages"

# %% [markdown]
# Dados do Champions

# %%
#Champions 2022
agents_vct2022_champion = agents_vct2022[(agents_vct2022['Tournament'] == "Valorant Champions 2022") & (agents_vct2022['Stage']==stage) & (agents_vct2022['Match Type'] == math_type) & (agents_vct2022['Map'] == map)]

#Pegando as colunas que interessam Agent e Pick Rate
agente_pick_rate_champion_2022 = agents_vct2022_champion[['Agent', 'Pick Rate']]

#Resetando o id
agente_pick_rate_champion_2022.reset_index(drop=True, inplace=True)
agente_pick_rate_champion_2022
# Out:
#         Agent Pick Rate
# 0     chamber       67%
# 1        fade       53%
# 2       viper       46%
# 3        kayo       45%
# 4        omen       35%
# 5        raze       34%
# 6        sova       33%
# 7        jett       31%
# 8      breach       26%
# 9        sage       22%
# 10      astra       22%
# 11       skye       21%
# 12  brimstone       20%
# 13    killjoy       16%
# 14       neon       16%
# 15    phoenix        6%
# 16     cypher        6%
# 17      reyna        1%
# 18       yoru        1%
# 19        iso        0%
# 20     harbor        0%
# 21      gekko        0%
# 22   deadlock        0%

# %% [markdown]
# Dados Pacífico

# %%
#Asia-Pacific
agents_vct2022_pacific = agents_vct2022[(agents_vct2022['Tournament'] == "Champions Tour Asia-Pacific: Last Chance Qualifier") & (agents_vct2022['Stage'] == stage) & (agents_vct2022['Match Type'] == math_type) & (agents_vct2022['Map'] == map)]

#Pegando as colunas que interessam Agent e Pick Rate
agente_pick_rate_pacific_2022 = agents_vct2022_pacific[['Agent', 'Pick Rate']]

#Resetando o id
agente_pick_rate_pacific_2022.reset_index(drop=True, inplace=True)
agente_pick_rate_pacific_2022
# Out:
#         Agent Pick Rate
# 0     chamber       72%
# 1       viper       43%
# 2        sova       41%
# 3        kayo       38%
# 4        jett       37%
# 5        fade       35%
# 6      breach       35%
# 7        skye       32%
# 8   brimstone       28%
# 9        raze       28%
# 10      astra       27%
# 11       neon       24%
# 12       omen       22%
# 13    killjoy       17%
# 14       sage       17%
# 15     cypher        3%
# 16        iso        0%
# 17    phoenix        0%
# 18     harbor        0%
# 19      reyna        0%
# 20      gekko        0%
# 21   deadlock        0%
# 22       yoru        0%

# %% [markdown]
# Dados North America

# %%
#North-America
agents_vct2022_north_america = agents_vct2022[(agents_vct2022['Tournament'] == "Champions Tour North America: Last Chance Qualifier") & (agents_vct2022['Stage']==stage) & (agents_vct2022['Match Type'] == math_type) & (agents_vct2022['Map'] == map)]

#Pegando as colunas que interessam Agent e Pick Rate
agente_pick_rate_north_america_2022 = agents_vct2022_north_america[['Agent', 'Pick Rate']]

#Resetando o id
agente_pick_rate_north_america_2022.reset_index(drop=True, inplace=True)
agente_pick_rate_north_america_2022
# Out:
#         Agent Pick Rate
# 0     chamber       84%
# 1        kayo       77%
# 2        fade       53%
# 3       viper       49%
# 4        sova       44%
# 5        omen       34%
# 6        sage       31%
# 7        raze       26%
# 8   brimstone       21%
# 9        jett       20%
# 10     breach       20%
# 11       neon       14%
# 12      astra        6%
# 13     cypher        6%
# 14    killjoy        6%
# 15       skye        4%
# 16    phoenix        3%
# 17       yoru        1%
# 18        iso        0%
# 19     harbor        0%
# 20      reyna        0%
# 21      gekko        0%
# 22   deadlock        0%

# %% [markdown]
# Dados South America

# %%
#South-America
agents_vct2022_south_america = agents_vct2022[(agents_vct2022['Tournament'] == "Champions Tour South America: Last Chance Qualifier") & (agents_vct2022['Stage']== stage) & (agents_vct2022['Match Type'] == math_type) & (agents_vct2022['Map'] == map)]

#Pegando as colunas que interessam Agent e Pick Rate
agente_pick_rate_south_america_2022 = agents_vct2022_south_america[['Agent', 'Pick Rate']]

#Resetando o id
agente_pick_rate_south_america_2022.reset_index(drop=True, inplace=True)
agente_pick_rate_south_america_2022
# Out:
#         Agent Pick Rate
# 0     chamber       79%
# 1        kayo       50%
# 2       viper       45%
# 3        sova       41%
# 4        raze       41%
# 5        jett       41%
# 6        fade       38%
# 7        omen       30%
# 8      breach       29%
# 9   brimstone       23%
# 10       sage       21%
# 11    killjoy       18%
# 12      astra       17%
# 13       skye       15%
# 14       neon       12%
# 15        iso        0%
# 16    phoenix        0%
# 17     harbor        0%
# 18      reyna        0%
# 19      gekko        0%
# 20   deadlock        0%
# 21     cypher        0%
# 22       yoru        0%

# %% [markdown]
# Dados EMEA

# %%
#Emea
agents_vct2022_emea = agents_vct2022[(agents_vct2022['Tournament'] == "Champions Tour EMEA: Last Chance Qualifier") & (agents_vct2022['Stage']== stage) & (agents_vct2022['Match Type'] == math_type) & (agents_vct2022['Map'] == map)]

#Pegando as colunas que interessam Agent e Pick Rate
agente_pick_rate_emea_2022 = agents_vct2022_emea[['Agent', 'Pick Rate']]

#Resetando o id
agente_pick_rate_emea_2022.reset_index(drop=True, inplace=True)
agente_pick_rate_emea_2022
# Out:
#         Agent Pick Rate
# 0     chamber       71%
# 1       viper       54%
# 2        raze       47%
# 3        fade       46%
# 4        kayo       40%
# 5        sova       33%
# 6      breach       32%
# 7        omen       32%
# 8       astra       28%
# 9        skye       26%
# 10       sage       24%
# 11       jett       19%
# 12    killjoy       13%
# 13       neon       13%
# 14  brimstone       13%
# 15     cypher        7%
# 16    phoenix        3%
# 17        iso        0%
# 18     harbor        0%
# 19      gekko        0%
# 20   deadlock        0%
# 21      reyna        0%
# 22       yoru        0%

# %%
#Retirando o % do Pick Rate e transformando em float
for i in [agente_pick_rate_champion_2022, agente_pick_rate_pacific_2022, agente_pick_rate_north_america_2022, agente_pick_rate_south_america_2022, agente_pick_rate_emea_2022]:
    
    #AVISO: esse i.loc[:,] foi indicação do Python para evitar um SettingWithCopyWarning e foi correção automática (também não entendi muito bem, mas funcionou)
    i.loc[:,'Pick Rate'] = pd.to_numeric(i['Pick Rate'].str.replace('%', ''), errors='coerce')
    
    #Transformando o Pick Rate em decimal
    i.loc[:,'Pick Rate'] = i['Pick Rate']/100

# %%
#Pega a lista de agentes por um dos dataframes já criados
agentes = list(agente_pick_rate_champion_2022['Agent'])

#Criando um contador para cada agente
contadores = [0]*23

#Percorendo cada dataframe
for i in [agente_pick_rate_champion_2022, agente_pick_rate_pacific_2022, agente_pick_rate_north_america_2022, agente_pick_rate_south_america_2022, agente_pick_rate_emea_2022]:
    
    #Zipando os agentes com os pick rates
    for j in zip(i['Agent'], i['Pick Rate']):

        #Adicionando o pick rate ao contador do agente
        contadores[agentes.index(j[0])] += j[1]
            
print(contadores)
# Out:
# [3.73, 2.25, 2.37, 2.5, 1.53, 1.76, 1.92, 1.4799999999999998, 1.4200000000000002, 1.15, 1.0, 0.9800000000000001, 1.05, 0.7000000000000001, 0.79, 0.12, 0.22, 0.01, 0.02, 0.0, 0.0, 0.0, 0.0]

# %%
#Criando um dataframe com os agentes e os pick rates final de todas as regiões
agents_pick_vct2022 = pd.DataFrame(list(zip(agentes, contadores)), columns =['Agent', 'Pick Rate'])
caminho = 'datasets-criados/agents_pick_vct2022.csv'
agents_pick_vct2022.to_csv(caminho, index=False)
print(agents_pick_vct2022)
# Out:
#         Agent  Pick Rate
# 0     chamber       3.73
# 1        fade       2.25
# 2       viper       2.37
# 3        kayo       2.50
# 4        omen       1.53
# 5        raze       1.76
# 6        sova       1.92
# 7        jett       1.48
# 8      breach       1.42
# 9        sage       1.15
# 10      astra       1.00
# 11       skye       0.98
# 12  brimstone       1.05
# 13    killjoy       0.70
# 14       neon       0.79
# 15    phoenix       0.12
# 16     cypher       0.22
# 17      reyna       0.01
# 18       yoru       0.02
# 19        iso       0.00
# 20     harbor       0.00
# 21      gekko       0.00
# 22   deadlock       0.00

# %%
#Plotando o gráfico de colunas
sns.set_theme(style="whitegrid")
plt.figure(figsize=(20,10))
sns.barplot(x='Agent', y='Pick Rate', data=agents_pick_vct2022, order=agents_pick_vct2022.sort_values('Pick Rate', ascending=False)['Agent'])
plt.show()
